# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import networkx as nx
import obsidiantools.api as otools
import pathlib

# %%
vault = otools.Vault(pathlib.Path.home() / pathlib.Path("obsidian/research"), include_subdirs=[
    "blogdraft", "logbook", "books", "papers", "mydevenv", "research"
]).connect().gather()
# Out:
# Front matter not populated for 2018__SIGMOD__The Case for Learned Index Structures.md: ParserError('while parsing a flow node', <yaml._yaml.Mark object at 0x12f7f06d0>, 'did not find expected node content', <yaml._yaml.Mark object at 0x12f7f1ad0>)
# Front matter not populated for 2018__SIGMOD__The Case for Learned Index Structures.md: ParserError('while parsing a flow node', <yaml._yaml.Mark object at 0x12f88e660>, 'did not find expected node content', <yaml._yaml.Mark object at 0x12f88fdd0>)
# Front matter not populated for 2021__NeurIPS__Open Bandit Dataset and Pipeline - Towards Realistic and Reproducible Off-Policy Evaluation.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12f88dbc0>)
# Front matter not populated for 2021__NeurIPS__Open Bandit Dataset and Pipeline - Towards Realistic and Reproducible Off-Policy Evaluation.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12f88e700>)
# Front matter not populated for 2019__KDD__Optuna - A Next-generation Hyperparameter Optimization Framework.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12f879c60>)
# Front matter not populated for 2019__KDD__Optuna - A Next-generation Hyperparameter Optimization Framework.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a43e840>)
# Front matter not populated for 2021__VLDB__Exathlon -  A Benchmark for Explainable Anomaly Detection over Time Series.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12f7f19e0>)
# Front matter not populated for 2021__VLDB__Exathlon -  A Benchmark for Explainable Anomaly Detection over Time Series.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12f7f1620>)
# Front matter not populated for 2018__Fault analysis and debugging of microservice systems - Industrial survey, benchmark system, and empirical study.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12f845440>)
# Front matter not populated for 2018__Fault analysis and debugging of microservice systems - Industrial survey, benchmark system, and empirical study.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12f846390>)
# Front matter not populated for 2021__JDSA__On the nature and types of anomalies - a review of deviations in data.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14b3a7880>)
# Front matter not populated for 2021__JDSA__On the nature and types of anomalies - a review of deviations in data.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12f88fec0>)
# Front matter not populated for 2021__KDD__TimeSHAP - Explaining Recurrent Models through Sequence Perturbations.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14b790ea0>)
# Front matter not populated for 2021__KDD__TimeSHAP - Explaining Recurrent Models through Sequence Perturbations.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12f8475b0>)
# Front matter not populated for 2021__IEEE Trans. Softw. Eng.__Locating Performance Regression Root Causes in the Field Operations of Web-based Systems - An Experience Report.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a4638d0>)
# Front matter not populated for 2021__IEEE Trans. Softw. Eng.__Locating Performance Regression Root Causes in the Field Operations of Web-based Systems - An Experience Report.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a460540>)
# Front matter not populated for 2019__ICSE-Companion__AIOps - Real-World Challenges and Research Innovations.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a31dee0>)
# Front matter not populated for 2019__ICSE-Companion__AIOps - Real-World Challenges and Research Innovations.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a31cfe0>)
# Front matter not populated for 2022__Mob__A Survey On Log Research Of AIOps - Methods and Trends.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14b791d00>)
# Front matter not populated for 2022__Mob__A Survey On Log Research Of AIOps - Methods and Trends.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14b790b30>)
# Front matter not populated for 2022__SSRN__Generic and Robust Root Cause Localization for Multi-Dimensional Data in Online Service Systems.md: ParserError('while parsing a flow node', <yaml._yaml.Mark object at 0x14b793f60>, 'did not find expected node content', <yaml._yaml.Mark object at 0x14b791710>)
# Front matter not populated for 2022__SSRN__Generic and Robust Root Cause Localization for Multi-Dimensional Data in Online Service Systems.md: ParserError('while parsing a flow node', <yaml._yaml.Mark object at 0x14b792430>, 'did not find expected node content', <yaml._yaml.Mark object at 0x14b792d90>)
# Front matter not populated for 2021__Middleware__CAT - content-aware tracing and analysis for distributed systems.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12f7f11c0>)
# Front matter not populated for 2021__Middleware__CAT - content-aware tracing and analysis for distributed systems.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12ff571a0>)
# Front matter not populated for 2021__ISSTA__Faster, deeper, easier - crowdsourcing diagnosis of microservice kernel failure from user space.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14b791c60>)
# Front matter not populated for 2021__ISSTA__Faster, deeper, easier - crowdsourcing diagnosis of microservice kernel failure from user space.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14b7918a0>)
# Front matter not populated for 2017__Ironies of automation - Still unresolved after all these years.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a3cbab0>)
# Front matter not populated for 2017__Ironies of automation - Still unresolved after all these years.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a3cbab0>)
# Front matter not populated for 2019__ICWS__Microscaler - Automatic scaling for microservices with an online learning approach.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a31e2f0>)
# Front matter not populated for 2019__ICWS__Microscaler - Automatic scaling for microservices with an online learning approach.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a31c400>)
# Front matter not populated for 2022__PMLR__Amortized Causal Discovery - Learning to Infer Causal Graphs from Time-Series Data.md: ScannerError('while scanning a quoted scalar', <yaml._yaml.Mark object at 0x12f80aed0>, 'found unexpected end of stream', <yaml._yaml.Mark object at 0x12f80a3e0>)
# Front matter not populated for 2022__PMLR__Amortized Causal Discovery - Learning to Infer Causal Graphs from Time-Series Data.md: ScannerError('while scanning a quoted scalar', <yaml._yaml.Mark object at 0x14a3cbd30>, 'found unexpected end of stream', <yaml._yaml.Mark object at 0x14a3cbab0>)
# Front matter not populated for 2018__ATC__SLAOrchestrator - Reducing the cost of performance SLAs for cloud data analytics.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a3cb6f0>)
# Front matter not populated for 2018__ATC__SLAOrchestrator - Reducing the cost of performance SLAs for cloud data analytics.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a31e8e0>)
# Front matter not populated for 2019__ATC__MArk - Exploiting Cloud Services for Cost-Effective, SLO-Aware Machine Learning Inference Serving.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a31ddf0>)
# Front matter not populated for 2019__ATC__MArk - Exploiting Cloud Services for Cost-Effective, SLO-Aware Machine Learning Inference Serving.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a31d300>)
# Front matter not populated for 2018__SIGMOD__The Case for Learned Index Structures.md: ParserError('while parsing a flow node', <yaml._yaml.Mark object at 0x14a49b290>, 'did not find expected node content', <yaml._yaml.Mark object at 0x14a49bba0>)
# Front matter not populated for 2021__NeurIPS__Open Bandit Dataset and Pipeline - Towards Realistic and Reproducible Off-Policy Evaluation.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12f85a0c0>)
# Front matter not populated for 2019__KDD__Optuna - A Next-generation Hyperparameter Optimization Framework.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12ff52890>)
# Front matter not populated for 2021__VLDB__Exathlon -  A Benchmark for Explainable Anomaly Detection over Time Series.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a43e1b0>)
# Front matter not populated for 2018__Fault analysis and debugging of microservice systems - Industrial survey, benchmark system, and empirical study.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x13ff36430>)
# Front matter not populated for 2021__JDSA__On the nature and types of anomalies - a review of deviations in data.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12f809990>)
# Front matter not populated for 2021__KDD__TimeSHAP - Explaining Recurrent Models through Sequence Perturbations.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x13ff36700>)
# Front matter not populated for 2021__IEEE Trans. Softw. Eng.__Locating Performance Regression Root Causes in the Field Operations of Web-based Systems - An Experience Report.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x13ff341d0>)
# Front matter not populated for 2019__ICSE-Companion__AIOps - Real-World Challenges and Research Innovations.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12ff38040>)
# Front matter not populated for 2022__Mob__A Survey On Log Research Of AIOps - Methods and Trends.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14b358950>)
# Front matter not populated for 2022__SSRN__Generic and Robust Root Cause Localization for Multi-Dimensional Data in Online Service Systems.md: ParserError('while parsing a flow node', <yaml._yaml.Mark object at 0x14b35a480>, 'did not find expected node content', <yaml._yaml.Mark object at 0x14b35ba60>)
# Front matter not populated for 2021__Middleware__CAT - content-aware tracing and analysis for distributed systems.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14b35bf10>)
# Front matter not populated for 2021__ISSTA__Faster, deeper, easier - crowdsourcing diagnosis of microservice kernel failure from user space.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a499990>)
# Front matter not populated for 2017__Ironies of automation - Still unresolved after all these years.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a499ee0>)
# Front matter not populated for 2019__ICWS__Microscaler - Automatic scaling for microservices with an online learning approach.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x12f859990>)
# Front matter not populated for 2022__PMLR__Amortized Causal Discovery - Learning to Infer Causal Graphs from Time-Series Data.md: ScannerError('while scanning a quoted scalar', <yaml._yaml.Mark object at 0x14b35ae30>, 'found unexpected end of stream', <yaml._yaml.Mark object at 0x14b35ba60>)
# Front matter not populated for 2018__ATC__SLAOrchestrator - Reducing the cost of performance SLAs for cloud data analytics.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a49b330>)
# Front matter not populated for 2019__ATC__MArk - Exploiting Cloud Services for Cost-Effective, SLO-Aware Machine Learning Inference Serving.md: ScannerError(None, None, 'mapping values are not allowed in this context', <yaml._yaml.Mark object at 0x14a4986d0>)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    df = pd.Series(nx.pagerank(vault.graph), name="pagerank").sort_values(ascending=False).head(n=50).to_frame()
    df['Rank'] = range(1, len(df.index) + 1)
    display(df)
# Out:
#                                                     pagerank  Rank
# AIOps                                               0.006349     1
# 機械学習                                                0.004988     2
# NetManAIOps                                         0.004590     3
# 異常検知                                                0.004514     4
# SLO                                                 0.003761     5
# SRE                                                 0.003408     6
# Transtracer                                         0.002846     7
# Interactive AIOps                                   0.002578     8
# PCアルゴリズム                                            0.002479     9
# TrainTicket                                         0.002446    10
# Transformer                                         0.002359    11
# Chaos Engineering                                   0.002306    12
# Pcalg                                               0.002139    13
# 深層学習                                                0.002115    14
# クラスタリング                                             0.002114    15
# eBPF                                                0.002013    16
# 2020__Webconf__AutoMAP - Diagnose Your Microser...  0.001997    17
# TSifter                                             0.001993    18
# PageRank                                            0.001879    19
# 2022__CSUR__Anomaly Detection and Failure Root ...  0.001873    20
# Distributed Tracing                                 0.001867    21
# ARISE Lab                                           0.001826    22
# 2016__SOCC__Why does the cloud stop computing? ...  0.001778    23
# Software Reliability Engineering                    0.001770    24
# 因果推論                                                0.001758    25
# Root Cause Analysis                                 0.001742    26
# VAE                                                 0.001702    27
# LLM                                                 0.001692    28
# 2014__INFOCOM__CauseInfer―Automatic and distrib...  0.001672    29
# Meltria                                             0.001628    30
# NLP                                                 0.001574    31
# DevOps                                              0.001574    32
# 2020__IWQoS__Localizing Failure Root Causes in ...  0.001537    33
# Granger因果性                                          0.001532    34
# 2013__PER__Root Cause Detection in a Service-Or...  0.001512    35
# FudanSELab                                          0.001489    36
# サーバーレスコンピューティング                                     0.001476    37
# 2018__Middleware__Sieve Actionable Insights fro...  0.001474    38
# 2020__Loghub - A Large Collection of System Log...  0.001446    39
# 2020__NOMS__MicroRCA - Root Cause Localization ...  0.001446    40
# YCSB                                                0.001446    41
# 2019__ICPE__PPTAM - Production and Performance ...  0.001446    42
# Attention機構                                         0.001427    43
# 信頼性工学                                               0.001427    44
# Launcher - dev                                      0.001424    45
# 相互相関                                                0.001412    46
# 2022__CLOUD__Localizing and Explaining Faults i...  0.001405    47
# 2020__ICSOC__A Systematic Mapping Study in AIOp...  0.001399    48
# 2022__CSUR__Anomaly Detection and Failure Root ...  0.001392    49
# ビルドトラップ                                             0.001380    50

# %% [markdown]
# ## Degree Centrality

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    df = pd.Series(nx.degree_centrality(vault.graph), name="degree centrality").sort_values(ascending=False).head(n=50).to_frame()
    df['Rank'] = range(1, len(df.index) + 1)
    display(df)
# Out:
#                                                     degree centrality  Rank
# 000 Index                                                    0.029918     1
# 異常検知                                                         0.019946     2
# 2020__IWQoS__Localizing Failure Root Causes in ...           0.019039     3
# NetManAIOps                                                  0.019039     4
# 2022__NeurIPS__Root Cause Analysis of Failures ...           0.018132     5
# AIOps                                                        0.018132     6
# 2021年の研究回想                                                   0.016319     7
# 機械学習                                                         0.015413     8
# 2022__arXiv__CausalRCA - Causal Inference based...           0.015413     9
# 2023__TDSC__DyCause - Crowdsourcing to Diagnose...           0.014506    10
# 2018__CCGRID__CloudRanger―Root Cause Identifica...           0.014506    11
# 入門 機械学習による異常検知                                               0.012693    12
# 2015__SIGMOD__k-Shape - Efficient and Accurate ...           0.012693    13
# 🏠Home                                                        0.012693    14
# 2018__ICSOC__Microscope―Pinpoint Performance Is...           0.012693    15
# 2021__ATC__Jump-Starting Multivariate Time Seri...           0.011786    16
# 2020__Webconf__AutoMAP - Diagnose Your Microser...           0.011786    17
# 📖Mathematics for Machine Learning                            0.011786    18
# 2017__SAC__DeepLog - Anomaly Detection and Diag...           0.010879    19
# 2013__PER__Root Cause Detection in a Service-Or...           0.010879    20
# 2021__CLOUD__Causal Modeling based Fault Locali...           0.009973    21
# SRE                                                          0.009973    22
# PCアルゴリズム                                                     0.009973    23
# 2020__ICWS__Root-Cause Metric Location for Micr...           0.009973    24
# SLO                                                          0.009973    25
# Seeking SRE                                                  0.009973    26
# ディープラーニングを支える技術                                              0.009973    27
# データマイニングによる異常検知                                              0.009066    28
# 2021__Journal-of-Software__TraceRank - Abnormal...           0.008160    29
# TrainTicket                                                  0.008160    30
# 深層学習                                                         0.008160    31
# PageRank                                                     0.008160    32
# ローカル開発環境                                                     0.008160    33
# SRE向けシステム系論文                                                 0.008160    34
# BPF Performance Tools                                        0.007253    35
# Chaos Engineering                                            0.007253    36
# 2021__CODS-COMAD__Evaluation of Causal Inferenc...           0.006346    37
# 2021__TIST__A Survey of AIOps Methods for Failu...           0.006346    38
# 2019__Review of Causal Discovery Methods Based ...           0.006346    39
# 2022__arXiv__DistAD―Software Anomaly Detection ...           0.006346    40
# TSifter                                                      0.006346    41
# 研究の育て方                                                       0.006346    42
# 2018__IWQoS__Robust and Rapid Clustering of KPI...           0.006346    43
# Transtracer                                                  0.006346    44
# Interactive AIOps                                            0.006346    45
# クラスタリング                                                      0.006346    46
# 2019__ICML__DAG-GNN - DAG Structure Learning wi...           0.006346    47
# 2019__ IWQoS__CoFlux - Robustly Correlating KPI...           0.006346    48
# 2019__Science Advances__Detecting and quantifyi...           0.006346    49
# 2020__ISSRE__Unsupervised Detection of Microser...           0.006346    50

# %% [markdown]
# ## Betweeness Centrality

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    df = pd.Series(nx.betweenness_centrality(vault.graph), name="betweenness centrality").sort_values(ascending=False).head(n=50).to_frame()
    df['Rank'] = range(1, len(df.index) + 1)
    display(df)
# Out:
#                                                     bwtweenness centrality
# 2020__IWQoS__Localizing Failure Root Causes in ...                0.000315  \
# 2013__PER__Root Cause Detection in a Service-Or...                0.000253
# 2018__CCGRID__CloudRanger―Root Cause Identifica...                0.000198
# 2020__Webconf__AutoMAP - Diagnose Your Microser...                0.000170
# 2018__ICSOC__Microscope―Pinpoint Performance Is...                0.000153
# 2021__CLOUD__Causal Modeling based Fault Locali...                0.000101
# 2023__TDSC__DyCause - Crowdsourcing to Diagnose...                0.000074
# 2019__Science Advances__Detecting and quantifyi...                0.000065
# 2017__HotOS__Gray Failure - The Achilles Heel o...                0.000061
# 2023__arXiv__Eadro - An End-to-End Troubleshoot...                0.000045
# 2021__CODS-COMAD__Evaluation of Causal Inferenc...                0.000039
# 2015__SIGMOD__k-Shape - Efficient and Accurate ...                0.000031
# 2007__Estimating High-Dimensional Directed Acyc...                0.000025
# 2018__Middleware__Sieve Actionable Insights fro...                0.000021
# 2014__INFOCOM__CauseInfer―Automatic and distrib...                0.000020
# 2022__arXiv__CausalRCA - Causal Inference based...                0.000017
# 2017__SAC__DeepLog - Anomaly Detection and Diag...                0.000013
# 2005__Pattern Recognit__Clustering of time seri...                0.000012
# 2019__ICML__DAG-GNN - DAG Structure Learning wi...                0.000012
# 2020__ISSRE__Unsupervised Detection of Microser...                0.000010
# 入門 機械学習による異常検知                                                    0.000010
# Seeking SRE                                                       0.000008
# 2018__Fault analysis and debugging of microserv...                0.000007
# ローカル開発環境                                                          0.000007
# 2021__ICSE__MicroDiag - Fine-grained Performanc...                0.000007
# データマイニングによる異常検知                                                   0.000007
# 2021__TIST__A Survey of AIOps Methods for Failu...                0.000005
# 2019__ESEC-FSE__Latent Error Prediction and Fau...                0.000005
# 2021__Journal-of-Software__TraceRank - Abnormal...                0.000005
# 2018__IWQoS__Robust and Rapid Clustering of KPI...                0.000005
# 2022__KDD__Causal Inference-Based Root Cause An...                0.000005
# Launcher - dev                                                    0.000005
# 研究の育て方                                                            0.000005
# 2019__TheWebConf__ε-Diagnosis― Unsupervised and...                0.000004
# 2019__ISSRE__FluxRank―A Widely-Deployable Frame...                0.000004
# 2005__SIGMOD__BRAID - Stream Mining through Gro...                0.000003
# 2022__CSUR__Anomaly Detection and Failure Root ...                0.000003
# 2020__VLDB__Monarch - Google’s Planet-Scale In-...                0.000003
# 2014__KDD__Correlating events with time series ...                0.000003
# 2022__Webconf__Robust System Instance Clusterin...                0.000003
# 2020__Applied Science__A Causality Mining and K...                0.000003
# Logbook                                                           0.000002
# 2022__arXiv__Heterogeneous Anomaly Detection fo...                0.000002
# 2020__IEEE-ACCESS__A Framework of Virtual War R...                0.000002
# 2022__arXiv__Constructing Large-Scale Real-Worl...                0.000002
# 2019__HotOS__Nines are Not Enough Meaningful Me...                0.000002
# 2020__ICLR__GRADIENT-BASED NEURAL DAG LEARNING                    0.000002
# 2010__Dapper, a Large-Scale Distributed Systems...                0.000002
# 2020__ICSOC__Localization of Operational Faults...                0.000002
# 2022__ICSE-SEIP__MicroHECL - High-Efficient Roo...                0.000002
#
#                                                     Rank
# 2020__IWQoS__Localizing Failure Root Causes in ...     1
# 2013__PER__Root Cause Detection in a Service-Or...     2
# 2018__CCGRID__CloudRanger―Root Cause Identifica...     3
# 2020__Webconf__AutoMAP - Diagnose Your Microser...     4
# 2018__ICSOC__Microscope―Pinpoint Performance Is...     5
# 2021__CLOUD__Causal Modeling based Fault Locali...     6
# 2023__TDSC__DyCause - Crowdsourcing to Diagnose...     7
# 2019__Science Advances__Detecting and quantifyi...     8
# 2017__HotOS__Gray Failure - The Achilles Heel o...     9
# 2023__arXiv__Eadro - An End-to-End Troubleshoot...    10
# 2021__CODS-COMAD__Evaluation of Causal Inferenc...    11
# 2015__SIGMOD__k-Shape - Efficient and Accurate ...    12
# 2007__Estimating High-Dimensional Directed Acyc...    13
# 2018__Middleware__Sieve Actionable Insights fro...    14
# 2014__INFOCOM__CauseInfer―Automatic and distrib...    15
# 2022__arXiv__CausalRCA - Causal Inference based...    16
# 2017__SAC__DeepLog - Anomaly Detection and Diag...    17
# 2005__Pattern Recognit__Clustering of time seri...    18
# 2019__ICML__DAG-GNN - DAG Structure Learning wi...    19
# 2020__ISSRE__Unsupervised Detection of Microser...    20
# 入門 機械学習による異常検知                                        21
# Seeking SRE                                           22
# 2018__Fault analysis and debugging of microserv...    23
# ローカル開発環境                                              24
# 2021__ICSE__MicroDiag - Fine-grained Performanc...    25
# データマイニングによる異常検知                                       26
# 2021__TIST__A Survey of AIOps Methods for Failu...    27
# 2019__ESEC-FSE__Latent Error Prediction and Fau...    28
# 2021__Journal-of-Software__TraceRank - Abnormal...    29
# 2018__IWQoS__Robust and Rapid Clustering of KPI...    30
# 2022__KDD__Causal Inference-Based Root Cause An...    31
# Launcher - dev                                        32
# 研究の育て方                                                33
# 2019__TheWebConf__ε-Diagnosis― Unsupervised and...    34
# 2019__ISSRE__FluxRank―A Widely-Deployable Frame...    35
# 2005__SIGMOD__BRAID - Stream Mining through Gro...    36
# 2022__CSUR__Anomaly Detection and Failure Root ...    37
# 2020__VLDB__Monarch - Google’s Planet-Scale In-...    38
# 2014__KDD__Correlating events with time series ...    39
# 2022__Webconf__Robust System Instance Clusterin...    40
# 2020__Applied Science__A Causality Mining and K...    41
# Logbook                                               42
# 2022__arXiv__Heterogeneous Anomaly Detection fo...    43
# 2020__IEEE-ACCESS__A Framework of Virtual War R...    44
# 2022__arXiv__Constructing Large-Scale Real-Worl...    45
# 2019__HotOS__Nines are Not Enough Meaningful Me...    46
# 2020__ICLR__GRADIENT-BASED NEURAL DAG LEARNING        47
# 2010__Dapper, a Large-Scale Distributed Systems...    48
# 2020__ICSOC__Localization of Operational Faults...    49
# 2022__ICSE-SEIP__MicroHECL - High-Efficient Roo...    50
